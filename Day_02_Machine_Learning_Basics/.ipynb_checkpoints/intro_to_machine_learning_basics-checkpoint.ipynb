# %%
import pandas as pd

data = {
    "Hours_Studied" : [1, 2, 3, 4, 5],
    "Marks" : [30, 40, 50, 60, 70]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Hours_Studied  Marks
# 0              1     30
# 1              2     40
# 2              3     50
# 3              4     60
# 4              5     70
